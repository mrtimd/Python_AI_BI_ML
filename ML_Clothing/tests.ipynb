# %% [markdown]
# Note: UI get input from user - apply this to something with a chart...
# https://code.visualstudio.com/docs/python/python-tutorial

# %%
import numpy

x = input("Type a number: ")
y = input("Type another number: ")

sum = int(x) + int(y)

print("The sum is: ", sum)

speed = [99,86,87,88,111,86,103,87,94,78,77,85,86]

x = numpy.mean(speed)

print(x)

# %% [markdown]
# Next test: this is a markup window
#
# test matplotlib with a scatter chart
#
# has agg error with matplotlib module - https://github.com/tctianchi/pyvenn/issues/3
#
# %matplotlib inline as last line
#
# The %matplotlib inline command tells the IPython environment to draw the plots immediately after the current cell. The drawn plots are shown below the code and stored in the notebook document for future reference.

# %%
#Three lines to make our compiler able to draw:
import sys
import matplotlib
#import tkinter
#matplotlib.use('Agg')

import matplotlib.pyplot as plt

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

plt.scatter(x, y)
plt.show()

#Two  lines to make our compiler able to draw:
#plt.savefig(sys.stdout.buffer)
#sys.stdout.flush()
# %matplotlib inline

# %% [markdown]
# Notes note code: check matplotlib version

# %%
import matplotlib

print(matplotlib.__version__)

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)
plt.show()
# %matplotlib inline

# %% [markdown]
# Note: Working example with magic py %matplotlib inline command

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 20, 100)  # Create a list of evenly-spaced numbers over the range
plt.plot(x, np.sin(x))       # Plot the sine of each x point
plt.show()                   # Display the plot
#%matplotlib inline

# %% [markdown]
# Note: User Input passed to variables to feed the chart
#
# --https://www.scaler.com/topics/matplotlib/matplotlib-inline/
#
# %matplotlib inline - added to show plot in Jupyter window

# %%
import matplotlib
#import tkinter
#matplotlib.use('Agg')

import matplotlib.pyplot as plt

#x = input("Type a number: ")
y = input("Type another number: ")

plt.scatter(x, y)
plt.show()

#Two  lines to make our compiler able to draw:
#plt.savefig(sys.stdout.buffer)
#sys.stdout.flush()
#%matplotlib inline
